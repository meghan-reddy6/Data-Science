# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello, World!")

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
a = input("Enter something: ")
print(a)

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
try:
    a = int(input("Enter a number: "))
    if a > 0:
        print("Positive")
    elif a == 0:
        print("Zero")
    else:
        print("Negative")
except Exception as ex:
    print("Error:", ex)

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
a = int(input("Enter a: "))
b = int(input("Enter b: "))
c = int(input("Enter C: "))

print("Max value is: ", max(a,b,c))

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
a = int(input("Enter a number: "))
fact = 1 
for i in range(1,a+1):
    fact*=i
print(fact)

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
a_int = 5
a_float = 5.0
a_string = 'five'
a_boolean = False

print(f'The number {a_int} is {type(a_int)}')
print(f'The number {a_float} is {type(a_float)}')
print(f'The number {a_string} is {type(a_string)}')
print(f'The number {a_boolean} is {type(a_boolean)}')

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a= int(input("Enter a number: "))
b = int(input("Enter b number: "))
a,b = b,a
print("After swapping: a =",a, "b =",b)

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
celcius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celcius * 9/5) + 32
print(f'Temperature in Fahrenheit: {fahrenheit}')

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
a = 'Hello'
b = 'world'
print(a+' '+b)

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
a = 14
print(f'{a} is integer : {isinstance(a,int)}')
# Out:
# 14 is integer : True

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
a = 14
b = 18

print(f'addition: {a+b}')
print(f'subtraction: {a-b}')
print(f'multiplication: {a*b}')
print(f'division: {a/b}')
# Out:
# addition: 32
# subtraction: -4
# multiplication: 252
# division: 0.7777777777777778

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
a = 14
b = 18

print(a==b)
print(a!=b)
print(a>b)
print(a<b)
# Out:
# False
# True
# False
# True

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a = True
b = True
print(a and b)
print(a or b)
print(not a)
# Out:
# True
# True
# False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
a = int(input("Enter a number: "))
print(f'{a} squared is {a**2}')
# Out:
# 5 squared is 25

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
a = int(input("Enter a number: "))
print('Even' if a % 2 == 0 else 'Odd')
# Out:
# Even

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
a = int(input("Enter a number: "))
print(f'Sum of  first {a} natural numbers is {a*(a+1)//2}')
# Out:
# Sum of  first 10 natural numbers is 55

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
a = int(input("Enter the year: "))
if((a%4==0 and a%100!=0) or (a%400==0)):
    print(f'{a} is a leap year')
# Out:
# 2004 is a leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
a = input("Enter a string: ")
print(f'string reversed is {a[::-1]}')
# Out:
# string reversed is egaugnalnohtypsisihtdlrowolleh

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
a = input("Enter a string: ")
print('True' if a==a.lower()[::-1] else 'False')
# Out:
# True

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
a = [1,53,2,52,6]
a.sort()
print(a)
# Out:
# [1, 2, 6, 52, 53]
